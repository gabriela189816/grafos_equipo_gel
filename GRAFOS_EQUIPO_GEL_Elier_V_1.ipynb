# %% [markdown]
# # TEMA 3: GRAFOS
# Integrantes del equipo:
# - Hérnandez Jiménez Elier Adin
# - Hilario Acuapan Gabriela
# - Pineda Gómez Luis Pineda
#
#
# ## HISTORIA
#
# La primera mencion de los grafos fue hecha por el matemático suizo Leonhard Euler, en una carta dirigida a la Academia de San Petersburgo, en 1736, en ella se aborda la solucion del problema de los puentes de Königsberg.
#
# El problema es el siguiente:
#
# ¿Es posible dar un paseo comenzando desde cualquiera de estas regiones, pasando por todos los puentes, recorriendo una sola vez cada uno y regresando al mismo lugar?
#
# ![image.png](attachment:cf16c108-751a-477a-9c94-20cbdaac142e.png)
#
# Figura 1. Puentes de Königsberg [1]
#
# Gustav Kirchhoff utilizo la teoria de grafos para calcular el voltaje y la corriente en los circuitos eléctricos, y desarrollar las leyes de Kirchhoff, se considera la primera como la primera apliacion de la teoría de grafos en la ingeniería.

# %% [markdown]
# ## INTRODUCCIÓN A GRAFOS
# CONCEPTOS BÁSICOS
#
# ### GRAFO
# ------------------------------
# *   Un **grafo** es un diagrama que consiste de puntos llamados **vertices**,
# conectados por líneas, llamadas **aristas** (edges); cada arista conecta exactamente dos vertices.
#
# ![image.png](attachment:4bd79a34-229c-4c33-80fd-f94f908e545b.png)
#
# **Figura 1**. Grafo [1]
#
# Un grafo puede ser utilizado para representar cualquier tipo de información que pueda ser modelada como objetos y que existe una relación entre estos objetos.
#
# ----------------------------
#
# ### DIGRAFO
# *   Un **digrafo** es un diagrama que consiste de puntos, llamados vertices, conectados por lineas directoras, llamadas **arcos**, cada arco conecta exactamente dos vertices.
#
# ![digraph.png](attachment:3bd75224-899b-4261-bd21-291d2c65235f.png)
# **Figura 2**. Digrafo [1].
#
# ----------------------------------
#
# Los problemas en teoría de grafos incluyen colorear grafos, encontrar un camino entre dos estados o nodos, o encontrar el camino más corto a través de un grafo, entre muchos otros.

# %% [markdown]
# ## GRAFOS EN MATEMÁTICAS
#
# La teoría de grafos se usa en matemáticas discretas y en la computación que es
#
#
#
#
#
#
# ### Notación
# Representar un grafo se puede hacer de varias maneras, la forma correcta de representarlos del algoritmo que se implemente.
#
# Un grafo puede representarse cómo:
#
# \begin{equation}
# G = (V,E)
# \end{equation}
#
# Este está definido por un conjunto de vértices, denominados V, y un conjunto de aristas, denominado E. El conjunto de aristas son subconjuntos de V donde cada miembro de E tiene cardinalidad 2.
#
# Considere el grafo no dirigido de la siguiente imagen.
#
# ![equipos_ejemplo.png](attachment:05fd8bfc-caf9-469f-9f42-81ba450558d7.png)
#
# Los conjuntos $V = \{A, E, G, L, W\}$ y $E = \{\{A, E\},\{A, W\},\{G, L\},\{G, W\},\{L, W\}\}$ definen este grafo. Dado que cada arista es en sí misma un conjunto de cardinalidad 2, en un grafo no dirigido, el orden de los vértices en cada conjunto de aristas no importa. Por ejemplo, $\{A, El\}$ es la misma arista que $\{El, A\}$.
#
#
# ## Representación
#
# #### Conjuntos
#
# $V=\{L,G,W,A,E\}$
#
# $E=\{\{A,E\},\{A,W\},\{G,L\},\{G,W\},\{L,W\}\}$
#
#
# ### Estructuras matriciales
#
# #### Matriz de adyacencia
#
# La matriz de adyacencia representa las relaciones de adyaciencia entre los vertices de un grafo, donde las columnas y las filas corresponden a los vertices del grafo.
#
# ![Matriz de adyaciencia.png](attachment:a3f2e3c1-d4bf-4936-a633-f0f8b502e905.png)
#
# ### Matriz de incidencia
#
# En esta matriz las filas represetnan vértices y las columnas representan aristas.
#
# ![Matriz de incidencia.png](attachment:c60b09f5-adb1-428c-bcba-8c097d018af7.png)
#
# ## Estructura de listas
#
# ### Lista de adyacencia
#
# Es un tipo de representación de grafos que consiste en una lista ligada donde se almacena la referencia a una lista de los vertices.
#
# ![Lista de adyaciencia.png](attachment:2a6602df-248f-4de6-9f1e-7c5990201cb7.png)
#
# ### Lista de incidencia
#
# En
#
# ![Lista de incidencia.png](attachment:2b8d78ea-b624-4189-892c-de9ce4d7d53a.png)

# %% [markdown]
# ## TIPOS DE GRAFOS
#
# ### Grafos ponderados
# Un grafo con peso es aquel en el que las aristas (edge) tiene un valor definido.
#
# $G = (V,E,W)$
#
# Donde $V=\{v_{1},...,v_{n}\}$ es un conjunto de vertices, $E=\{e_{1},...,e_{n}\}$ es un conjunto de aristas y $W=\{w_{1},...,w_{n}\}$ es un conjunto de pesos que estan asociadas a cada arista.
#
# ![grafo_ponderado.png](attachment:23e68853-ef1b-4f3b-a747-62afd986b941.png)

# %% [markdown]
# ## ALGORITMOS DE GRAFOS
#
# ALGORITMO BFS
#
#
# ALGORITMO DFS
#
#
# ALGORITMO DIJKTRA
#
# El algoritmo de Dijkstra es famoso en Ciencias de la Computación y tiene muchas aplicaciones, desde redes hasta planificación de la construcción
#
#
# ALGORITMO ESTRELLA

# %% [markdown]
# ## GRAFOS EN PYTHON
#
# Python no tiene definido un tipo de dato para Grafos de manera nativa. Para trabajar con ellos, se puede utilizar una biblioteca externa como *networkx* o se pueden implementar manualmente.
#
# ## **networks**
# NetworkX es un paquete de Python para la creación, manipulación y estudio de la estructura, dinámica y funciones de redes complejas.
#
# ![networkx.png](attachment:3e594e06-757f-4f09-908f-47d2b109f7fa.png)
#
# Sitio Oficial: https://networkx.org/
#
# Instalación:
#
# ## ALGORITMO A*

# %% [markdown]
# ## Bibliografía sugerida.
# 1. A Beginner's Guide to Graph Theory by W.D. Wallis (2007).
# 2. A textbook of graph therory by R. Balakrishnan and K. Ranganathan (2012).
# 3. Graph Theory with Algorithms and its Applications by Santanu Saha Ray (2013).
# 4. Basic Graph Theory by Md. Saidur Rahman (2017).
# 5. Graph Theory by Reinhard Diestel (2017).
# 6. Graps and applications. An introductory Approach by Joan M. Aldous and Robin J. Wilson (2009).
